# %% [markdown]
# <a href="https://colab.research.google.com/github/nnilayy/CAFA-5-Protein-Function-Prediction/blob/main/Midi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# !pip install fortepyan

# %%
from datasets import load_dataset
dataset = load_dataset("roszcz/internship-midi-data-science", split="train")
dataset
# Out:
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/roszcz___parquet/roszcz--internship-midi-data-science-5506ea35081b41a4/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Dataset({
#     features: ['notes', 'control_changes', 'user', 'record_id'],
#     num_rows: 6
# })

# %%
import pandas as pd
record = dataset[0]
df = pd.DataFrame(record["notes"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88887 entries, 0 to 88886
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   end       88887 non-null  float64
#  1   pitch     88887 non-null  int64
#  2   start     88887 non-null  float64
#  3   velocity  88887 non-null  int64
# dtypes: float64(2), int64(2)
# memory usage: 2.7 MB

# %%
df.head()
# Out:
#         end  pitch     start  velocity
# 0  2.058438     42  1.934219        74
# 1  2.990469     66  1.935573        84
# 2  2.044531     30  1.948229        76
# 3  2.613073     49  2.556146        77
# 4  2.618333     54  2.564844        59

# %%
df['time']=df['end']-df['start']
df.head()
# Out:
#         end  pitch     start  velocity      time
# 0  2.058438     42  1.934219        74  0.124219
# 1  2.990469     66  1.935573        84  1.054896
# 2  2.044531     30  1.948229        76  0.096302
# 3  2.613073     49  2.556146        77  0.056927
# 4  2.618333     54  2.564844        59  0.053490
